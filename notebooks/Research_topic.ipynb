# %% [markdown]
# # Data Jobs
#
# ***Data-related jobs are considered the most popular career of 2021. Because of the increasing demand for data specialists, many professionals expect a
# very high compensation for performing jobs in this field. Thus we decided to evaluate the impact different variables have on the expected salary, so we could adjust our expectations to the current international market. This is the dataset processed from the Stack overflow Annual Developers Survey.***
#
# ## Content: There are 2 files
# ***processed_data.csv***
# This is the data pre-processed from the original dataset with all the Developer type converted into dummies variables:
#
# - Data Scientist or Machine Learning Specialist
# - Database Administrator
# - Data Analyst
# - Business Analyst and Data Engineer)
# - Together with other variables such as: Country, Education level, Employment, Job Satisfaction, Organization size, Undergraduate major, Year of coding as professionals
#
# ***survey_final.csv:***
# The original dataset comes from the Stack overflow Annual Developers Survey, and for this dataset we will only consider the respondents that considered themselves already in a data related job (Data Scientist, Machine Learning Specialist, Database Administrator, Data Analyst, Business Analyst and Data Engineer)
#
# ## Acknowledgements
# This dataset is processed from the Stack Overflow Annual Survey result from 2017 to 2020
# The original datasets can be found at: https://insights.stackoverflow.com/survey and also on Kaggle.

# %%
import pandas as pd
import numpy as np 
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
df = pd.read_csv('../data/processed_data.csv')
df
# Out:
#        Year                   Hobbyist  ConvertedComp  \
# 0      2017                  Yes, both    43750.00000
# 1      2017  Yes, I program as a hobby    51282.05128
# 2      2017                         No    25000.00000
# 3      2017  Yes, I program as a hobby   100000.00000
# 4      2017                  Yes, both    27000.00000
# ...     ...                        ...            ...
# 33596  2020                        Yes   225000.00000
# 33597  2020                        Yes      369.00000
# 33598  2020                         No    38484.00000
# 33599  2020                        Yes   140000.00000
# 33600  2020                        Yes   129718.00000
#
#                                     Country  \
# 0                            United Kingdom
# 1                                   Denmark
# 2                                    Israel
# 3                             United States
# 4                                   Ukraine
# ...                                     ...
# 33596                         United States
# 33597  Venezuela, Bolivarian Republic of...
# 33598                               Hungary
# 33599                         United States
# 33600                               Germany
#
#                                                  EdLevel  \
# 0                                      Bachelor's degree
# 1      Some college/university study without earning ...
# 2      Some college/university study without earning ...
# 3      Some college/university study without earning ...
# 4                                        Master's degree
# ...                                                  ...
# 33596  Some college/university study without earning ...
# 33597  Some college/university study without earning ...
# 33598                                    Master's degree
# 33599                                    Doctoral degree
# 33600                                    Master's degree
#
#                                               Employment  JobSat  \
# 0                                     Employed full-time     4.0
# 1                                     Employed part-time    10.0
# 2                                     Employed full-time     6.0
# 3                                     Employed full-time     5.0
# 4                                     Employed full-time     7.0
# ...                                                  ...     ...
# 33596                                 Employed full-time     8.0
# 33597                                 Employed full-time     2.0
# 33598  Independent contractor, freelancer, or self-em...     8.0
# 33599                                 Employed full-time     8.0
# 33600  Independent contractor, freelancer, or self-em...     8.0
#
#                                                  OrgSize  \
# 0                                       2 to 9 employees
# 1                                   100 to 499 employees
# 2                               5,000 to 9,999 employees
# 3                                     20 to 99 employees
# 4                                   100 to 499 employees
# ...                                                  ...
# 33596                           1,000 to 4,999 employees
# 33597                           1,000 to 4,999 employees
# 33598  Just me - I am a freelancer, sole proprietor, ...
# 33599                           10,000 or more employees
# 33600  Just me - I am a freelancer, sole proprietor, ...
#
#                        UndergradMajor  YearsCodePro  \
# 0                    Computer science           2.0
# 1                    Computer science           3.0
# 2                    Computer science           4.0
# 3                    Computer science          15.0
# 4                    Computer science           5.0
# ...                               ...           ...
# 33596       Mathematics or statistics          15.0
# 33597                Computer science          27.0
# 33598                      Humanities          12.0
# 33599  Another engineering discipline          12.0
# 33600  Another engineering discipline           9.0
#
#        Data scientist or machine learning specialist  Database administrator  \
# 0                                                  1                       1
# 1                                                  1                       0
# 2                                                  1                       0
# 3                                                  0                       1
# 4                                                  0                       1
# ...                                              ...                     ...
# 33596                                              0                       0
# 33597                                              0                       1
# 33598                                              0                       0
# 33599                                              1                       0
# 33600                                              0                       1
#
#        Data or business analyst  Engineer, data
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                           NaN             NaN
# 3                           NaN             NaN
# 4                           NaN             NaN
# ...                         ...             ...
# 33596                       0.0             1.0
# 33597                       0.0             1.0
# 33598                       1.0             0.0
# 33599                       1.0             1.0
# 33600                       0.0             0.0
#
# [33601 rows x 14 columns]

# %%
df1 = pd.read_csv('../data/survey_final.csv')
df1
# Out:
#         Year                   Hobbyist  ConvertedComp             Country  \
# 0       2020                        Yes            NaN             Germany
# 1       2020                         No            NaN      United Kingdom
# 2       2020                        Yes            NaN  Russian Federation
# 3       2020                        Yes            NaN             Albania
# 4       2020                        Yes            NaN       United States
# ...      ...                        ...            ...                 ...
# 303586  2017  Yes, I program as a hobby        58000.0       United States
# 303587  2017                         No            NaN           Venezuela
# 303588  2017  Yes, I program as a hobby            NaN              Canada
# 303589  2017  Yes, I program as a hobby        40000.0       United States
# 303590  2017                         No            NaN             Ireland
#
#                    DatabaseDesireNextYear  \
# 0                    Microsoft SQL Server
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                        MySQL;PostgreSQL
# ...                                   ...
# 303586                         SQL Server
# 303587                  MySQL; PostgreSQL
# 303588                                NaN
# 303589                              MySQL
# 303590  MongoDB; Redis; MySQL; PostgreSQL
#
#                                DatabaseWorkedWith  \
# 0       Elasticsearch;Microsoft SQL Server;Oracle
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                   MySQL;PostgreSQL;Redis;SQLite
# ...                                           ...
# 303586                 MongoDB; SQL Server; MySQL
# 303587                     SQL Server; PostgreSQL
# 303588                                        NaN
# 303589                                        NaN
# 303590                                        NaN
#
#                                                   DevType  \
# 0       Developer, desktop or enterprise applications;...
# 1                 Developer, full-stack;Developer, mobile
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 303586  Web developer; Developer with a statistics or ...
# 303587                                                NaN
# 303588               Web developer; Systems administrator
# 303589                    Web developer; Mobile developer
# 303590                                                NaN
#
#                                                   EdLevel  \
# 0         Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 1            Bachelor's degree (B.A., B.S., B.Eng., etc.)
# 2                                                     NaN
# 3         Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 4            Bachelor's degree (B.A., B.S., B.Eng., etc.)
# ...                                                   ...
# 303586                                  Bachelor's degree
# 303587                                    Master's degree
# 303588  Some college/university study without earning ...
# 303589                                  Bachelor's degree
# 303590                                  Bachelor's degree
#
#                                                Employment  \
# 0       Independent contractor, freelancer, or self-em...
# 1                                      Employed full-time
# 2                                                     NaN
# 3                                                     NaN
# 4                                      Employed full-time
# ...                                                   ...
# 303586                                 Employed full-time
# 303587                                 Employed full-time
# 303588                                 Employed full-time
# 303589                                 Employed full-time
# 303590                                 Employed full-time
#
#                        JobSat                      LanguageDesireNextYear  \
# 0          Slightly satisfied                      C#;HTML/CSS;JavaScript
# 1           Very dissatisfied                                Python;Swift
# 2                         NaN                    Objective-C;Python;Swift
# 3       Slightly dissatisfied                                         NaN
# 4                         NaN                             Java;Ruby;Scala
# ...                       ...                                         ...
# 303586                      3    C#; JavaScript; Python; SQL; VB.NET; VBA
# 303587                    NaN                                   Java; SQL
# 303588                     10                                         NaN
# 303589                      7                      JavaScript; PHP; Swift
# 303590                      8  Java; JavaScript; PHP; Python; Ruby; Swift
#
#                                        LanguageWorkedWith  \
# 0                                  C#;HTML/CSS;JavaScript
# 1                                        JavaScript;Swift
# 2                                Objective-C;Python;Swift
# 3                                                     NaN
# 4                                       HTML/CSS;Ruby;SQL
# ...                                                   ...
# 303586  C#; Python; R; Ruby; Rust; Scala; TypeScript; ...
# 303587  C#; Java; JavaScript; PHP; Python; Ruby; SQL; ...
# 303588                                                NaN
# 303589                           Clojure; Erlang; Haskell
# 303590                                                NaN
#
#                          OrgSize  \
# 0               2 to 9 employees
# 1       1,000 to 4,999 employees
# 2                            NaN
# 3             20 to 99 employees
# 4                            NaN
# ...                          ...
# 303586      100 to 499 employees
# 303587      100 to 499 employees
# 303588        10 to 19 employees
# 303589   Fewer than 10 employees
# 303590  10,000 or more employees
#
#                                            UndergradMajor      YearsCodePro
# 0       Computer science, computer engineering, or sof...                27
# 1       Computer science, computer engineering, or sof...                 4
# 2                                                     NaN               NaN
# 3       Computer science, computer engineering, or sof...                 4
# 4       Computer science, computer engineering, or sof...                 8
# ...                                                   ...               ...
# 303586                                   A social science      1 to 2 years
# 303587            Computer programming or Web development               NaN
# 303588  Information technology, networking, or system ...  Less than a year
# 303589           Computer science or software engineering      3 to 4 years
# 303590           Computer science or software engineering      5 to 6 years
#
# [303591 rows x 15 columns]
